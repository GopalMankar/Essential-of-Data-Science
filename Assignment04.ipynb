# %% [markdown]
# <a href="https://colab.research.google.com/github/GopalMankar/Essential-of-Data-Science/blob/main/Assignment04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/AQI and Lat Long of Countries2.csv')
print(df.to_string())
# Out:
#                                                    Country                      City  AQI Value                    AQI Category  CO AQI Value                 CO AQI Category  Ozone AQI Value              Ozone AQI Category  NO2 AQI Value NO2 AQI Category  PM2.5 AQI Value              PM2.5 AQI Category      lat       lng
# 0                                       Russian Federation                Praskoveya         51                        Moderate             1                            Good               36                            Good              0             Good               51                        Moderate  44.7444   44.2031
# 1                                                   Brazil          Presidente Dutra         41                            Good             1                            Good                5                            Good              1             Good               41                            Good  -5.2900  -44.4900
# ...

# %%
from sqlalchemy import true
df1 = df[['Country','City','AQI Value']]
print(df1)
df1.to_csv("AQI and Lat Long of Countries",index=True)
# Out:
#                  Country              City  AQI Value
# 0     Russian Federation        Praskoveya         51
# 1                 Brazil  Presidente Dutra         41
# 2                 Brazil  Presidente Dutra         41
# 3                  Italy   Priolo Gargallo         66
# 4                 Poland         Przasnysz         34
# ...                  ...               ...        ...
# 4002        South Africa            Benoni        123
# 4003         Netherlands            Bergen         39
# 4004         Netherlands            Bergen         39
# 4005         Netherlands            Bergen         39
# 4006         Netherlands            Bergen         39
#
# [4007 rows x 3 columns]

# %%
print(df1.describe())
# Out:
#          AQI Value
# count  4007.000000
# mean     63.183928
# std      46.127164
# min      10.000000
# 25%      38.000000
# 50%      52.000000
# 75%      69.000000
# max     500.000000

# %%
print(df1.mean)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of                  Country              City  AQI Value  \
# 0     Russian Federation        Praskoveya         51
# 1                 Brazil  Presidente Dutra         41
# 2                 Brazil  Presidente Dutra         41
# 3                  Italy   Priolo Gargallo         66
# 4                 Poland         Przasnysz         34
# ...                  ...               ...        ...
# 4002        South Africa            Benoni        123
# 4003         Netherlands            Bergen         39
# 4004         Netherlands            Bergen         39
# 4005         Netherlands            Bergen         39
# 4006         Netherlands            Bergen         39
#
#                         AQI Category  CO AQI Value CO AQI Category  \
# 0                           Moderate             1            Good
# 1                               Good             1            Good
# ...

# %%
print(df1.max())
# Out:
# City                                          Zwettl
# AQI Value                                        500
# AQI Category                          Very Unhealthy
# CO AQI Value                                     133
# CO AQI Category       Unhealthy for Sensitive Groups
# Ozone AQI Value                                  206
# Ozone AQI Category                    Very Unhealthy
# NO2 AQI Value                                     91
# NO2 AQI Category                            Moderate
# PM2.5 AQI Value                                  500
# PM2.5 AQI Category                    Very Unhealthy
# lat                                          69.4167
# lng                                         176.1667
# dtype: object
# ...

# %%
print(df1['AQI Value'].max())
# Out:
# 500

# %%
print(df1['AQI Value'].describe())
# Out:
# count    4007.000000
# mean       63.183928
# std        46.127164
# min        10.000000
# 25%        38.000000
# 50%        52.000000
# 75%        69.000000
# max       500.000000
# Name: AQI Value, dtype: float64

# %%
print(df1['AQI Value'].min())
# Out:
# 10

# %%
print(df1.count())
# Out:
# Country      3929
# City         4007
# AQI Value    4007
# dtype: int64

# %%
print(df.head())
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2              Brazil  Presidente Dutra         41         Good             1
# 3               Italy   Priolo Gargallo         66     Moderate             1
# 4              Poland         Przasnysz         34         Good             1
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good                5               Good              1
# 3            Good               39               Good              2
# 4            Good               34               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat      lng
# ...

# %%
print(df.shape)
# Out:
# (4007, 14)

# %%
print(df1['AQI Value'].mean())
# Out:
# 63.183928125779886
